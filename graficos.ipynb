# %% [markdown]
# <a href="https://colab.research.google.com/github/avieirajr/kanban/blob/main/graficos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np

# %%
x = np.array([1,2,3,4,5])
y = np.array([2,3,5,7,9])

# %%
plt.plot(x, y)

# %%
normal = np.random.randn(1000)

# %%
plt.plot(np.sort(normal))

# %%
sns.kdeplot(normal)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# #Medidas

# %%
np.mean(normal)
# Out:
# np.float64(-0.007371735298534497)

# %%
np.median(normal)
# Out:
# np.float64(-0.012209716108394705)

# %%
# prompt: como extrair  a moda do array normal

import scipy.stats as stats

normal = [1,2,3,4,5,6,7,8,9]

# %%
stats.mode(normal)
# Out:
# ModeResult(mode=np.int64(1), count=np.int64(1))

# %%
np.median(normal)
# Out:
# np.float64(5.0)

# %%
np.mean(normal)
# Out:
# np.float64(5.0)

# %%
print(np.sort(normal))
sns.kdeplot(np.sort(normal))
# Out:
# [1 2 3 4 5 6 7 8 9]
# <Axes: ylabel='Density'>

# %%
np.histogram(normal)
normal = np.random.randn(1000)

# %%
plt.hist(normal,40)
# Out:
# (array([ 2.,  1.,  0.,  0.,  3.,  0.,  3.,  0.,  4., 12., 11., 17., 16.,
#         29., 51., 45., 41., 54., 69., 75., 73., 63., 66., 79., 57., 55.,
#         46., 38., 25., 15., 14., 13.,  6.,  4.,  4.,  1.,  3.,  1.,  2.,
#          2.]),
#  array([-3.79307041, -3.61129145, -3.42951249, -3.24773353, -3.06595458,
#         -2.88417562, -2.70239666, -2.5206177 , -2.33883875, -2.15705979,
#         -1.97528083, -1.79350187, -1.61172291, -1.42994396, -1.248165  ,
#         -1.06638604, -0.88460708, -0.70282813, -0.52104917, -0.33927021,
#         -0.15749125,  0.02428771,  0.20606666,  0.38784562,  0.56962458,
#          0.75140354,  0.93318249,  1.11496145,  1.29674041,  1.47851937,
#          1.66029832,  1.84207728,  2.02385624,  2.2056352 ,  2.38741416,
#          2.56919311,  2.75097207,  2.93275103,  3.11452999,  3.29630894,
#          3.4780879 ]),
#  <BarContainer object of 40 artists>)
