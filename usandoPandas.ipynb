# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
#importar biblioteca
import pandas as pd

# %%
ca_df = pd.read_csv("ca-2023-02.csv", sep=";")

# %%
display(ca_df.tail(10))
# Out:
#        Regiao - Sigla Estado - Sigla   Municipio  \
# 472414             NE             BA  JAGUAQUARA
# 472415             SE             SP     BIRIGUI
# 472416             SE             SP     BIRIGUI
# 472417             SE             SP     BIRIGUI
# 472418              N             AP     SANTANA
# 472419              N             AP     SANTANA
# 472420              N             AP     SANTANA
# 472421             NE             PI    PARNAIBA
# 472422             NE             PI    PARNAIBA
# 472423             NE             PI    PARNAIBA
#
#                                                   Revenda  \
# 472414  JAGUAQUARA COMERCIO DE COMBUSTIVEIS E LUBRIFIC...
# 472415               AUTO POSTO BENEDETTI DE BIRIGUI LTDA
# 472416               AUTO POSTO BENEDETTI DE BIRIGUI LTDA
# 472417               AUTO POSTO BENEDETTI DE BIRIGUI LTDA
# 472418                 POSTO DE COMBUSTIVEIS JARDINS LTDA
# 472419                 POSTO DE COMBUSTIVEIS JARDINS LTDA
# 472420                 POSTO DE COMBUSTIVEIS JARDINS LTDA
# 472421                          MAXXI DELTA PETROLEO LTDA
# 472422                          MAXXI DELTA PETROLEO LTDA
# 472423                          MAXXI DELTA PETROLEO LTDA
#
#             CNPJ da Revenda                              Nome da Rua  \
# 472414   10.503.164/0001-95                          RUA RUI BARBOSA
# 472415   50.610.749/0001-29                AVENIDA EUCLIDES MIRAGAIA
# 472416   50.610.749/0001-29                AVENIDA EUCLIDES MIRAGAIA
# 472417   50.610.749/0001-29                AVENIDA EUCLIDES MIRAGAIA
# 472418   10.522.077/0012-38  RODOVIA COMANDANTE PEDRO SALVADOR DINIZ
# 472419   10.522.077/0012-38  RODOVIA COMANDANTE PEDRO SALVADOR DINIZ
# 472420   10.522.077/0012-38  RODOVIA COMANDANTE PEDRO SALVADOR DINIZ
# 472421   47.221.821/0001-11        AVENIDA DEPUTADO PINHEIRO MACHADO
# 472422   47.221.821/0001-11        AVENIDA DEPUTADO PINHEIRO MACHADO
# 472423   47.221.821/0001-11        AVENIDA DEPUTADO PINHEIRO MACHADO
#
#        Numero Rua Complemento         Bairro        Cep             Produto  \
# 472414        655         NaN         CENTRO  45345-000              ETANOL
# 472415       1678         NaN    VILA PONTES  16200-130            GASOLINA
# 472416       1678         NaN    VILA PONTES  16200-130          DIESEL S10
# 472417       1678         NaN    VILA PONTES  16200-130              ETANOL
# 472418       3005     ANEXO A  VILA AMAZONAS  68926-214            GASOLINA
# 472419       3005     ANEXO A  VILA AMAZONAS  68926-214              DIESEL
# 472420       3005     ANEXO A  VILA AMAZONAS  68926-214          DIESEL S10
# 472421       3570     LETRA A          PIAUÍ  64208-335            GASOLINA
# 472422       3570     LETRA A          PIAUÍ  64208-335  GASOLINA ADITIVADA
# 472423       3570     LETRA A          PIAUÍ  64208-335              ETANOL
#
#        Data da Coleta Valor de Venda  Valor de Compra Unidade de Medida  \
# 472414     27/12/2023           4,12              NaN        R$ / litro
# 472415     27/12/2023           4,87              NaN        R$ / litro
# 472416     27/12/2023           5,39              NaN        R$ / litro
# 472417     27/12/2023           2,84              NaN        R$ / litro
# 472418     28/12/2023           5,75              NaN        R$ / litro
# 472419     28/12/2023           6,44              NaN        R$ / litro
# 472420     28/12/2023           6,49              NaN        R$ / litro
# 472421     27/12/2023            5,2              NaN        R$ / litro
# 472422     27/12/2023            5,2              NaN        R$ / litro
# 472423     27/12/2023           3,99              NaN        R$ / litro
#
#         Bandeira
# 472414    BRANCA
# 472415    BRANCA
# 472416    BRANCA
# 472417    BRANCA
# 472418  IPIRANGA
# 472419  IPIRANGA
# 472420  IPIRANGA
# 472421    BRANCA
# 472422    BRANCA
# 472423    BRANCA

# %%
display(ca_df[10:20])
# Out:
#    Regiao - Sigla Estado - Sigla   Municipio  \
# 10              N             AC  RIO BRANCO
# 11              N             AC  RIO BRANCO
# 12              N             AC  RIO BRANCO
# 13              N             AC  RIO BRANCO
# 14              N             AC  RIO BRANCO
# 15              N             AC  RIO BRANCO
# 16              N             AC  RIO BRANCO
# 17              N             AC  RIO BRANCO
# 18              N             AC  RIO BRANCO
# 19              N             AC  RIO BRANCO
#
#                                            Revenda      CNPJ da Revenda  \
# 10                        CODEPE COMBUSTIVEIS LTDA   08.220.930/0001-62
# 11                        CODEPE COMBUSTIVEIS LTDA   08.220.930/0001-62
# 12                        CODEPE COMBUSTIVEIS LTDA   08.220.930/0001-62
# 13                        CODEPE COMBUSTIVEIS LTDA   08.220.930/0001-62
# 14                        CODEPE COMBUSTIVEIS LTDA   08.220.930/0001-62
# 15  COMDEPE COMERCIO DE DERIVADOS DE PETROLEO LTDA   01.198.443/0001-00
# 16  COMDEPE COMERCIO DE DERIVADOS DE PETROLEO LTDA   01.198.443/0001-00
# 17  COMDEPE COMERCIO DE DERIVADOS DE PETROLEO LTDA   01.198.443/0001-00
# 18  COMDEPE COMERCIO DE DERIVADOS DE PETROLEO LTDA   01.198.443/0001-00
# 19                             POSTO VILLAGE LTDA.   06.906.483/0001-74
#
#                                           Nome da Rua Numero Rua  \
# 10  RODOVIA BR-364 (RIO BRANCO-CRUZEIRO DO SUL) - ...       2755
# 11  RODOVIA BR-364 (RIO BRANCO-CRUZEIRO DO SUL) - ...       2755
# 12  RODOVIA BR-364 (RIO BRANCO-CRUZEIRO DO SUL) - ...       2755
# 13  RODOVIA BR-364 (RIO BRANCO-CRUZEIRO DO SUL) - ...       2755
# 14  RODOVIA BR-364 (RIO BRANCO-CRUZEIRO DO SUL) - ...       2755
# 15                          ESTRADA JARBAS PASSARINHO        115
# 16                          ESTRADA JARBAS PASSARINHO        115
# 17                          ESTRADA JARBAS PASSARINHO        115
# 18                          ESTRADA JARBAS PASSARINHO        115
# 19                         RUA ANTONIO DA ROCHA VIANA        S/N
#
#                                       Complemento              Bairro  \
# 10                      LOTE  01/02/03/04/05 E 33  PORTAL DA AMAZONIA
# 11                      LOTE  01/02/03/04/05 E 33  PORTAL DA AMAZONIA
# 12                      LOTE  01/02/03/04/05 E 33  PORTAL DA AMAZONIA
# 13                      LOTE  01/02/03/04/05 E 33  PORTAL DA AMAZONIA
# 14                      LOTE  01/02/03/04/05 E 33  PORTAL DA AMAZONIA
# 15                                            NaN              PLACAS
# 16                                            NaN              PLACAS
# 17                                            NaN              PLACAS
# 18                                            NaN              PLACAS
# 19  CONJ. VILLAGE W. MARCIEL QD. 02 LOTES 01 A 04        VILA IVONETE
#
#           Cep             Produto Data da Coleta Valor de Venda  \
# 10  69915-630            GASOLINA     05/07/2023           6,29
# 11  69915-630  GASOLINA ADITIVADA     05/07/2023           6,29
# 12  69915-630              DIESEL     05/07/2023           5,96
# 13  69915-630          DIESEL S10     05/07/2023           5,99
# 14  69915-630              ETANOL     05/07/2023           4,59
# 15  69900-970            GASOLINA     05/07/2023           6,22
# 16  69900-970  GASOLINA ADITIVADA     05/07/2023           6,29
# 17  69900-970              DIESEL     05/07/2023           5,75
# 18  69900-970          DIESEL S10     05/07/2023           5,85
# 19  69914-610            GASOLINA     05/07/2023           6,26
#
#     Valor de Compra Unidade de Medida       Bandeira
# 10              NaN        R$ / litro  VIBRA ENERGIA
# 11              NaN        R$ / litro  VIBRA ENERGIA
# 12              NaN        R$ / litro  VIBRA ENERGIA
# 13              NaN        R$ / litro  VIBRA ENERGIA
# 14              NaN        R$ / litro  VIBRA ENERGIA
# 15              NaN        R$ / litro  VIBRA ENERGIA
# 16              NaN        R$ / litro  VIBRA ENERGIA
# 17              NaN        R$ / litro  VIBRA ENERGIA
# 18              NaN        R$ / litro  VIBRA ENERGIA
# 19              NaN        R$ / litro  VIBRA ENERGIA

# %%
print(ca_df.shape)
# Out:
# (472424, 16)

# %%
print(ca_df.dtypes)
# Out:
# Regiao - Sigla               object
# Estado - Sigla               object
# Municipio                    object
# Revenda                      object
# CNPJ da Revenda              object
# Nome da Rua                  object
# Numero Rua                   object
# Complemento                  object
# Bairro                       object
# Cep                          object
# Produto                      object
# Data da Coleta       datetime64[ns]
# Valor de Venda              float64
# Valor de Compra             float64
# Unidade de Medida            object
# Bandeira                     object
# dtype: object

# %%
ca_df["Valor de Venda"] = ca_df["Valor de Venda"].str.replace(",", ".")
ca_df["Valor de Venda"] = ca_df["Valor de Venda"].astype(float)

# %%
ca_df["Valor de Compra"] = ca_df["Valor de Compra"].astype(float)

# %%
ca_df["Data da Coleta"] = pd.to_datetime(ca_df["Data da Coleta"], format="%d/%m/%Y")

# %%
print(ca_df.describe())
# Out:
#                       Data da Coleta  Valor de Venda  Valor de Compra
# count                         472424   472424.000000              0.0
# mean   2023-09-29 20:44:50.322252544        5.377879              NaN
# min              2023-07-03 00:00:00        2.390000              NaN
# 25%              2023-08-15 00:00:00        4.890000              NaN
# 50%              2023-10-02 00:00:00        5.670000              NaN
# 75%              2023-11-14 00:00:00        5.990000              NaN
# max              2023-12-29 00:00:00        9.790000              NaN
# std                              NaN        0.939501              NaN

# %%
display(ca_df[['Produto', 'Valor de Venda']])
# Out:
#                    Produto  Valor de Venda
# 0                 GASOLINA            4.87
# 1               DIESEL S10            4.88
# 2                   ETANOL            3.27
# 3                 GASOLINA            6.95
# 4               DIESEL S10            6.85
# ...                    ...             ...
# 472419              DIESEL            6.44
# 472420          DIESEL S10            6.49
# 472421            GASOLINA            5.20
# 472422  GASOLINA ADITIVADA            5.20
# 472423              ETANOL            3.99
#
# [472424 rows x 2 columns]

# %%
display(ca_df.loc[1110])
# Out:
# Regiao - Sigla                                 NE
# Estado - Sigla                                 MA
# Municipio                                PINHEIRO
# Revenda              C. BARROS CASTRO & CIA LTDA.
# CNPJ da Revenda                02.900.938/0001-93
# Nome da Rua                   AVENIDA PAULO RAMOS
# Numero Rua                                    600
# Complemento                                     A
# Bairro                                     CENTRO
# Cep                                     65200-000
# Produto                        GASOLINA ADITIVADA
# Data da Coleta                2023-07-03 00:00:00
# Valor de Venda                               5.94
# Valor de Compra                               NaN
# Unidade de Medida                      R$ / litro
# Bandeira                                   ALESAT
# Name: 1110, dtype: object

# %%
gas_df = ca_df[ca_df["Produto"] == "GASOLINA"]

# %%
display(gas_df[['Municipio', 'Valor de Venda']])
# Out:
#               Municipio  Valor de Venda
# 0              SOROCABA            4.87
# 3       CRUZEIRO DO SUL            6.95
# 5       CRUZEIRO DO SUL            6.93
# 10           RIO BRANCO            6.29
# 15           RIO BRANCO            6.22
# ...                 ...             ...
# 472409              UBA            5.29
# 472411       JAGUAQUARA            5.64
# 472415          BIRIGUI            4.87
# 472418          SANTANA            5.75
# 472421         PARNAIBA            5.20
#
# [121261 rows x 2 columns]

# %%
# Out:
#        Regiao - Sigla Estado - Sigla Municipio  \
# 6060               SE             SP    SANTOS
# 6063               SE             SP    SANTOS
# 6068               SE             SP    SANTOS
# 6071               SE             SP    SANTOS
# 11243              SE             SP    SANTOS
# ...               ...            ...       ...
# 460201             SE             SP    SANTOS
# 465377             SE             SP    SANTOS
# 465691             SE             SP    SANTOS
# 465836             SE             SP    SANTOS
# 466108             SE             SP    SANTOS
#
#                                                Revenda      CNPJ da Revenda  \
# 6060                                POSTO AVENIDA LTDA   09.047.352/0001-77
# 6063       POSTO DE SERVICOS TRAVESSIA DE SANTOS LTDA.   08.521.038/0001-11
# 6068     POSTO DE SERVICOS AUTOMOTIVOS SAO RAFAEL LTDA   44.968.618/0001-15
# 6071                        AUTO POSTO TAMBURELLO LTDA   01.277.960/0001-66
# 11243                        AUTO POSTO VIA PRAIA LTDA   10.203.539/0001-00
# ...                                                ...                  ...
# 460201                          AUTO POSTO BRUMAR LTDA   00.135.799/0001-23
# 465377                       AUTO POSTO VIA PRAIA LTDA   10.203.539/0001-00
# 465691  VIA PORTO COMERCIO E SERVICOS AUTOMOTIVOS LTDA   10.221.953/0001-33
# 465836                       AUTO POSTO PRAIAMAR LTDA.   09.005.834/0001-64
# 466108                AUTO POSTO ESTRELA SANTISTA LTDA   10.517.064/0001-18
#
#                                   Nome da Rua Numero Rua Complemento  \
# 6060                      AVENIDA PEDRO LESSA       1192         NaN
# 6063       AVENIDA ALMIRANTE SALDANHA DA GAMA        200         NaN
# 6068          AVENIDA NOSSA SENHORA DE FATIMA        609         NaN
# 6071                      AVENIDA AFONSO PENA        227         NaN
# 11243                   RUA ALEXANDRE MARTINS         61         NaN
# ...                                       ...        ...         ...
# 460201                      AVENIDA ANA COSTA        341         NaN
# 465377                  RUA ALEXANDRE MARTINS         61         NaN
# 465691  AVENIDA GOVERNADOR MARIO COVAS JUNIOR        738         NaN
# 465836                    AVENIDA PEDRO LESSA       1000        1010
# 466108                        RUA AFONSO PENA        240         NaN
#
#                 Bairro        Cep Produto Data da Coleta  Valor de Venda  \
# 6060         APARECIDA  11025-000  ETANOL     2023-07-03            3.44
# 6063    PONTA DA PRAIA  11030-401  ETANOL     2023-07-03            3.99
# 6068    CHICO DE PAULA  11085-203  ETANOL     2023-07-03            3.59
# 6071            MACUCO  11020-001  ETANOL     2023-07-03            4.19
# 11243        APARECIDA  11025-201  ETANOL     2023-07-03            4.17
# ...                ...        ...     ...            ...             ...
# 460201         GONZAGA  11055-000  ETANOL     2023-12-25            3.99
# 465377       APARECIDA  11025-201  ETANOL     2023-12-25            3.74
# 465691        ESTUARIO  11020-300  ETANOL     2023-12-25            3.69
# 465836  PONTA DA PRAIA  11025-000  ETANOL     2023-12-25            3.79
# 466108          MACUCO  11020-000  ETANOL     2023-12-25            3.39
#
#         Valor de Compra Unidade de Medida       Bandeira
# 6060                NaN        R$ / litro         BRANCA
# 6063                NaN        R$ / litro       IPIRANGA
# 6068                NaN        R$ / litro         BRANCA
# 6071                NaN        R$ / litro  VIBRA ENERGIA
# 11243               NaN        R$ / litro         BRANCA
# ...                 ...               ...            ...
# 460201              NaN        R$ / litro       IPIRANGA
# 465377              NaN        R$ / litro       IPIRANGA
# 465691              NaN        R$ / litro       IPIRANGA
# 465836              NaN        R$ / litro          VIBRA
# 466108              NaN        R$ / litro       IPIRANGA
#
# [363 rows x 16 columns]

# %%
eta_santos_df = ca_df[(ca_df["Produto"] == "ETANOL") & (ca_df["Municipio"] == "SANTOS")][["Municipio"]] # Corrected line
display(eta_santos_df)
# Out:
#        Municipio
# 6060      SANTOS
# 6063      SANTOS
# 6068      SANTOS
# 6071      SANTOS
# 11243     SANTOS
# ...          ...
# 460201    SANTOS
# 465377    SANTOS
# 465691    SANTOS
# 465836    SANTOS
# 466108    SANTOS
#
# [363 rows x 1 columns]

# %%
# !pip install nbformat
# Out:
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/dist-packages (from nbformat) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.10/dist-packages (from nbformat) (5.7.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat) (0.22.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.3.6)

# %%
import plotly.express as px
#df_new = px.data.gapminder().query("continent == 'Oceania'")
df_new = px.data.gapminder().query("country in ['Canada', 'Brazil']")

# %%
fig = px.line(df_new, x='year', y = 'lifeExp', title ='Bora lá!!!', color = 'country', markers=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b4085902-1a5a-41cd-9a71-2678d7a63a10" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b4085902-1a5a-41cd-9a71-2678d7a63a10")) {                    Plotly.newPlot(                        "b4085902-1a5a-41cd-9a71-2678d7a63a10",                        [{"hovertemplate":"country=Brazil\u003cbr\u003eyear=%{x}\u003cbr\u003elifeExp=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Brazil","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Brazil","orientation":"v","showlegend":true,"x":[1952,1957,1962,1967,1972,1977,1982,1987,1992,1997,2002,2007],"xaxis":"x","y":[50.917,53.285,55.665,57.632,59.504,61.489,63.33600000000001,65.205,67.057,69.388,71.006,72.39],"yaxis":"y","type":"scatter"},{"hovertemplate":"country=Canada\u003cbr\u003eyear=%{x}\u003cbr\u003elifeExp=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Canada","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Canada","orientation":"v","showlegend":true,"x":[1952,1957,1962,1967,1972,1977,1982,1987,1992,1997,2002,2007],"xaxis":"x","y":[68.75,69.96,71.3,72.13,72.88,74.21,75.76,76.86,77.95,78.61,79.77,80.653],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"ty ...
